# %% [markdown]
# # Bayesian Optimisation Ray Tune
# - This file performs hyperparameter optimization using Bayesian Optimization with the HyperBand scheduler from Ray Tune.
# - It integrates a Vision Transformer model, optimizing over a manually defined configuration space using ConfigSpace.

# %%
import os
from datetime import datetime
import logging
import ConfigSpace as CS
import ray
from ray import tune
from ray.tune import Tuner, TuneConfig, with_resources
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.search.bohb import TuneBOHB
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision.datasets import ImageFolder
import torch.nn.functional as F

# %%
# Constants
EPOCHS = 30
CLASSES = 3
DATA_DIR = "/home/sur06423/wacv_paper/wacv_paper/data/pizza_steak_sushi"

# %%
# Setup logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s", handlers=[
    logging.FileHandler(f"hyperopt_results_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"),
    logging.StreamHandler()
])

# %%
class VisionTransformerModel:
    """Encapsulates the Vision Transformer model setup."""
    
    @staticmethod
    def define_model(use_gpu, num_classes=CLASSES):
        """Configures a Vision Transformer for image classification with a frozen backbone.
        
        Args:
            use_gpu (bool): Whether to utilize CUDA if available.
            num_classes (int): The number of classes for the output layer.

        Returns:
            Tuple[torch.nn.Module, torchvision.transforms]: Configured model and associated transforms.
        """
        pretrained_weights = torchvision.models.ViT_B_16_Weights.DEFAULT
        model = torchvision.models.vit_b_16(weights=pretrained_weights)
        for param in model.parameters():
            param.requires_grad = False
        model.heads = nn.Linear(in_features=768, out_features=num_classes)
        return model, pretrained_weights.transforms()

# %%
class DataLoaderFactory:
    """Handles the creation of dataset loaders for training and validation."""

    @staticmethod
    def get_data_loaders(transform, batch_size=256):
        """Creates training and validation data loaders.

        Args:
            transform (callable): A function/transform that takes in a PIL image and returns a transformed version.
            batch_size (int): Number of images in each batch of data.

        Returns:
            Tuple[torch.utils.data.DataLoader, torch.utils.data.DataLoader]: Data loaders for training and validation.
        """
        train_dataset = ImageFolder(root=os.path.join(DATA_DIR, "train"), transform=transform)
        val_dataset = ImageFolder(root=os.path.join(DATA_DIR, "test"), transform=transform)
        train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
        return train_loader, val_loader

# %%
class Metrics:
    """Provides methods to calculate evaluation metrics for model performance."""
    
    @staticmethod
    def calculate_balanced_accuracy(y_pred, y_true, num_classes=CLASSES):
        """Calculates the balanced accuracy across given predictions and true labels.

        Args:
            y_pred (torch.Tensor): Predictions from the model.
            y_true (torch.Tensor): Actual labels from the dataset.
            num_classes (int): Number of different classes in the dataset.

        Returns:
            float: Balanced accuracy score.
        """
        correct_per_class = torch.zeros(num_classes, device=y_pred.device)
        total_per_class = torch.zeros(num_classes, device=y_pred.device)
        for c in range(num_classes):
            true_positives = ((y_pred == c) & (y_true == c)).sum()
            condition_positives = (y_true == c).sum()
            correct_per_class[c] = true_positives.float()
            total_per_class[c] = condition_positives.float()
        recall_per_class = correct_per_class / total_per_class.clamp(min=1)
        return recall_per_class.mean().item()

# %%
def create_config_space():
    """Defines and returns the configuration space for hyperparameter tuning using ConfigSpace."""
    config_space = CS.ConfigurationSpace()
    optimizer = CS.CategoricalHyperparameter("optimizer", ["adam", "sgd", "adamw"])
    scheduler = CS.CategoricalHyperparameter("scheduler", ["constant", "cosineannealinglr", "linearinterpolationlr"])
    lr = CS.UniformFloatHyperparameter("lr", lower=1e-5, upper=1e-1, log=True)
    momentum = CS.UniformFloatHyperparameter("momentum", lower=0.8, upper=0.99)
    weight_decay = CS.UniformFloatHyperparameter("weight_decay", lower=0, upper=0.1)
    end_lr = CS.UniformFloatHyperparameter("end_lr", lower=1e-3, upper=1e-2, log=True)
    use_gpu = CS.CategoricalHyperparameter("use_gpu", [True])  # Explicitly set "use_gpu" to True
    config_space.add([optimizer, scheduler, lr, momentum, weight_decay, end_lr, use_gpu])
    return config_space

# %% [markdown]
# # Class API for Hyperparameter Optimisation Ray Tune

# %%
class TrainViT(tune.Trainable):
    """A trainable class for Ray Tune that handles the training and validation of a Vision Transformer model."""
    
    def setup(self, config):
        """Prepares the model, data loaders, optimizer, and scheduler for training based on the configuration provided.

        Args:
            config (dict): Configuration dictionary containing hyperparameters and model settings.
        """
        self.device = torch.device("cuda" if torch.cuda.is_available() and config["use_gpu"] else "cpu")
        self.model, transforms = VisionTransformerModel.define_model(config["use_gpu"])
        self.model.to(self.device)
        self.train_loader, self.val_loader = DataLoaderFactory.get_data_loaders(transforms)
        self.optimizer = self._initialize_optimizer(config)
        self.scheduler = self._initialize_scheduler(config)

    def _initialize_optimizer(self, config):
        """Initializes the optimizer based on the configuration.

        Args:
            config (dict): Configuration dictionary specifying the optimizer type and parameters.

        Returns:
            torch.optim.Optimizer: Initialized optimizer.
        """
        optimizer_map = {
            "adam": lambda: optim.Adam(self.model.parameters(), lr=config["lr"], weight_decay=config["weight_decay"]),
            "sgd": lambda: optim.SGD(self.model.parameters(), lr=config["lr"], momentum=config["momentum"], weight_decay=config["weight_decay"]),
            "adamw": lambda: optim.AdamW(self.model.parameters(), lr=config["lr"], weight_decay=config["weight_decay"])
        }
        return optimizer_map[config["optimizer"]]()

    def _initialize_scheduler(self, config):
        """Initializes the learning rate scheduler based on the configuration.

        Args:
            config (dict): Configuration dictionary specifying the scheduler type and parameters.

        Returns:
            Optional[torch.optim.lr_scheduler._LRScheduler]: Initialized scheduler, or None if not applicable.
        """
        scheduler_map = {
            "constant": lambda: None,
            "cosineannealinglr": lambda: optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=EPOCHS),
            "linearinterpolationlr": lambda: optim.lr_scheduler.LambdaLR(
                self.optimizer,
                lr_lambda=lambda epoch: (1 - float(epoch) / EPOCHS) + (float(epoch) / EPOCHS) * config["end_lr"] / config["lr"]
            )
        }
        return scheduler_map[config["scheduler"]]()

    def step(self):
        """Executes a single step of training and validation.

        Returns:
            dict: A dictionary containing training and validation loss and accuracy.
        """
        train_loss, train_acc = self._train_one_epoch()
        if self.scheduler:
            self.scheduler.step()
        val_loss, val_acc = self._validate_one_epoch()
        return {"loss": train_loss, "accuracy": train_acc, "val_loss": val_loss, "val_acc": val_acc}

    def _train_one_epoch(self):
        """Conducts a single epoch of training on the entire training dataset.

        Returns:
            Tuple[float, float]: Training loss and Balanced accuracy.
        """
        self.model.train()
        running_loss = 0.0
        all_predictions, all_labels = [], []
        for inputs, labels in self.train_loader:
            inputs, labels = inputs.to(self.device), labels.to(self.device)
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = F.cross_entropy(outputs, labels)
            loss.backward()
            self.optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            all_predictions.append(torch.argmax(torch.softmax(outputs, dim=1), dim=1))
            all_labels.append(labels)
        avg_loss = running_loss / len(self.train_loader.dataset)
        balanced_acc = Metrics.calculate_balanced_accuracy(torch.cat(all_predictions), torch.cat(all_labels))
        return avg_loss, balanced_acc

    def _validate_one_epoch(self):
        """Conducts validation on the entire validation dataset and computes loss and accuracy.

        Returns:
            Tuple[float, float]: Validation loss and Balanced accuracy.
        """
        self.model.eval()
        running_loss = 0.0
        all_predictions, all_labels = [], []
        with torch.no_grad():
            for inputs, labels in self.val_loader:
                inputs, labels = inputs.to(self.device), labels.to(self.device)
                outputs = self.model(inputs)
                loss = F.cross_entropy(outputs, labels)
                running_loss += loss.item() * inputs.size(0)
                all_predictions.append(torch.argmax(torch.softmax(outputs, dim=1), dim=1))
                all_labels.append(labels)
        avg_loss = running_loss / len(self.val_loader.dataset)
        balanced_acc = Metrics.calculate_balanced_accuracy(torch.cat(all_predictions), torch.cat(all_labels))
        return avg_loss, balanced_acc

    def save_checkpoint(self, checkpoint_dir):
        """Saves the current model and optimizer state to a checkpoint.

        Args:
            checkpoint_dir (str): Directory path to save the checkpoint.

        Returns:
            str: Path to the checkpoint file.
        """
        checkpoint_path = os.path.join(checkpoint_dir, "checkpoint.pth")
        torch.save({
            "model_state_dict": self.model.state_dict(),
            "optimizer_state_dict": self.optimizer.state_dict(),
        }, checkpoint_path)
        return checkpoint_dir

    def load_checkpoint(self, checkpoint_dir):
        """Loads the model and optimizer state from a checkpoint.

        Args:
            checkpoint_dir (str): Directory path from which to load the checkpoint.
        """
        checkpoint_path = os.path.join(checkpoint_dir, "checkpoint.pth")
        checkpoint = torch.load(checkpoint_path)
        self.model.load_state_dict(checkpoint["model_state_dict"])
        self.optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

# %%
def setup_library_paths():
    """Configures additional library paths required for GPU computation.
        Note: These paths are specific to my local server.
              You might not need to define them.
        
        Adds specified library paths to the LD_LIBRARY_PATH environment variable
        if they are not already included, ensuring GPU dependencies are located.
    """
    library_paths = [
        "/usr/lib/xorg-nvidia-525.116.04/lib/x86_64-linux-gnu",
        "/usr/lib/xorg/lib/x86_64-linux-gnu",
        "/usr/lib/xorg-nvidia-535.113.01/lib/x86_64-linux-gnu"
    ]
    # Current LD_LIBRARY_PATH from the environment
    current_ld_library_path = os.environ.get('LD_LIBRARY_PATH', '')
    # Add only new paths that are not already in the LD_LIBRARY_PATH
    new_paths = [path for path in library_paths if path not in current_ld_library_path]
    # Update the environment variable
    os.environ['LD_LIBRARY_PATH'] = ':'.join(new_paths + [current_ld_library_path])
    print("Updated LD_LIBRARY_PATH:")
    print(os.environ['LD_LIBRARY_PATH'])

# %%
def main():
    """Main function to set up and execute the hyperparameter tuning."""
    ray.shutdown()
    # Initialise the Ray cluster with dashboard included
    ray.init(num_cpus=40, num_gpus=4, include_dashboard=True)
    # Setup GPU library paths
    setup_library_paths()

    # Use ConfigSpace directly with TuneBOHB
    config_space = create_config_space()
    bohb_hyperband = HyperBandForBOHB(time_attr="training_iteration", max_t=EPOCHS, reduction_factor=2, stop_last_trials=False)
    
    # Set metric and mode in TuneBOHB
    bohb_search = TuneBOHB(config_space, metric="val_acc", mode="max")  # Specify metric and mode
    bohb_search = tune.search.ConcurrencyLimiter(bohb_search, max_concurrent=4)

    run_config = ray.train.RunConfig(
        name="Bayesian_Trial_Exp",
        stop={"training_iteration": EPOCHS},
        checkpoint_config=ray.train.CheckpointConfig(checkpoint_frequency=1, checkpoint_at_end=True)
    )

    tuner = Tuner(
        trainable=with_resources(
            TrainViT,
            resources=lambda config: {"gpu": 1, "cpu": 3} if config.get("use_gpu", False) else {"cpu": 3}
        ),
        param_space={},  # Leave param_space empty as TuneBOHB uses config_space
        tune_config=TuneConfig(
            metric="val_acc",
            mode="max",
            scheduler=bohb_hyperband,
            search_alg=bohb_search,
            num_samples=32
        ),
        run_config=run_config
    )

    results = tuner.fit()
    best_result = results.get_best_result(metric="val_acc", mode="max")
    logging.info("Best trial config: {}".format(best_result.config))
    logging.info("Best trial final validation accuracy: {}".format(best_result.metrics["val_acc"]))

    ray.shutdown()

# %%
main()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-02 11:54:03</td></tr>
# <tr><td>Running for: </td><td>00:33:59.24        </td></tr>
# <tr><td>Memory:      </td><td>22.5/503.4 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=28 total_brackets=3<br>Round #0:<br>  Bracket(Max Size (n)=2, Milestone (r)=16, completed=81.0%): {TERMINATED: 20} <br>  Bracket(Max Size (n)=2, Milestone (r)=24, completed=67.9%): {TERMINATED: 12} <br>Logical resource usage: 6.0/40 CPUs, 2.0/4 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name       </th><th>status    </th><th>loc               </th><th style="text-align: right;">    end_lr</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  momentum</th><th>optimizer  </th><th>scheduler           </th><th>use_gpu  </th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">       loss</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  val_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>TrainViT_e8b9dbef</td><td>TERMINATED</td><td>10.56.7.46:2067308</td><td style="text-align: right;">0.00859156</td><td style="text-align: right;">0.000137338</td><td style="text-align: right;">  0.95441 </td><td>adam       </td><td>constant            </td><td>True     </td><td style="text-align: right;">    0.0702793 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         29.2324</td><td style="text-align: right;">1.1514     </td><td style="text-align: right;">  0.282222</td><td style="text-align: right;"> 1.04254  </td></tr>
# <tr><td>TrainViT_1b154b15</td><td>TERMINATED</td><td>10.56.7.46:2068273</td><td style="text-align: right;">0.00746483</td><td style="text-align: right;">2.41354e-05</td><td style="text-align: right;">  0.88815 </td><td>adamw      </td><td>linearinterpola_3a50</td><td>True     </td><td style="text-align: right;">    0.0646759 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         28.0405</td><td style="text-align: right;">1.09805    </td><td style="text-align: right;">  0.426222</td><td style="text-align: right;"> 1.07918  </td></tr>
# <tr><td>TrainViT_dfa71a53</td><td>TERMINATED</td><td>10.56.7.46:2068390</td><td style="text-align: right;">0.00664807</td><td style="text-align: right;">1.0345e-05 </td><td style="text-align: right;">  0.979274</td><td>sgd        </td><td>constant            </td><td>True     </td><td style="text-align: right;">    0.0149964 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         27.2705</td><td style="text-align: right;">1.11672    </td><td style="text-align: right;">  0.322222</td><td style="text-align: right;"> 1.10355  </td></tr>
# <tr><td>TrainViT_5bc1a2ff</td><td>TERMINATED</td><td>10.56.7.46:2068493</td><td style="text-align: right;">0.00645562</td><td style="text-align: right;">0.00014916 </td><td style="text-align: right;">  0.913602</td><td>sgd        </td><td>constant            </td><td>True     </td><td style="text-align: right;">    0.0345147 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         28.1918</td><td style="text-align: right;">1.09194    </td><td style="text-align: right;">  0.371111</td><td style="text-align: right;"> 1.01704  </td></tr>
# <tr><td>TrainViT_c4960fb4</td><td>TERMINATED</td><td>10.56.7.46:2068599</td><td style="text-align: right;">0.00575781</td><td style="text-align: right;">6.40682e-05</td><td style="text-align: right;">  0.867219</td><td>sgd        </td><td>cosineannealinglr   </td><td>True     </td><td style="text-align: right;">    0.0240613 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         28.8873</td><td style="text-align: right;">1.10373    </td><td style="text-align: right;">  0.327556</td><td style="text-align: right;"> 1.06689  </td></tr>
# <tr><td>TrainViT_b84013fd</td><td>TERMINATED</td><td>10.56.7.46:2074646</td><td style="text-align: right;">0.00939692</td><td style="text-align: right;">0.0265329  </td><td style="text-align: right;">  0.962829</td><td>adamw      </td><td>cosineannealinglr   </td><td>True     </td><td style="text-align: right;">    0.0675284 </td><td style="text-align: right;">     8</td><td style="text-align: right;">        231.448 </td><td style="text-align: right;">0.00780827 </td><td style="text-align: right;">  0.998667</td><td style="text-align: right;"> 0.118852 </td></tr>
# <tr><td>TrainViT_d634c15b</td><td>TERMINATED</td><td>10.56.7.46:2071537</td><td style="text-align: right;">0.00330186</td><td style="text-align: right;">0.00374415 </td><td style="text-align: right;">  0.885066</td><td>adamw      </td><td>cosineannealinglr   </td><td>True     </td><td style="text-align: right;">    0.0501659 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         54.644 </td><td style="text-align: right;">0.138685   </td><td style="text-align: right;">  0.948444</td><td style="text-align: right;"> 0.0802933</td></tr>
# <tr><td>TrainViT_f10a3b05</td><td>TERMINATED</td><td>10.56.7.46:2068971</td><td style="text-align: right;">0.00846438</td><td style="text-align: right;">1.71086e-05</td><td style="text-align: right;">  0.911234</td><td>adam       </td><td>cosineannealinglr   </td><td>True     </td><td style="text-align: right;">    0.0683006 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         27.8968</td><td style="text-align: right;">1.03582    </td><td style="text-align: right;">  0.504444</td><td style="text-align: right;"> 1.02502  </td></tr>
# <tr><td>TrainViT_315372e7</td><td>TERMINATED</td><td>10.56.7.46:2069123</td><td style="text-align: right;">0.0054966 </td><td style="text-align: right;">6.61444e-05</td><td style="text-align: right;">  0.976973</td><td>adamw      </td><td>linearinterpola_6070</td><td>True     </td><td style="text-align: right;">    0.00864234</td><td style="text-align: right;">     1</td><td style="text-align: right;">         27.9164</td><td style="text-align: right;">1.10641    </td><td style="text-align: right;">  0.390222</td><td style="text-align: right;"> 1.04539  </td></tr>
# <tr><td>TrainViT_376966ef</td><td>TERMINATED</td><td>10.56.7.46:2069232</td><td style="text-align: right;">0.0091004 </td><td style="text-align: right;">2.1922e-05 </td><td style="text-align: right;">  0.945915</td><td>adam       </td><td>constant            </td><td>True     </td><td style="text-align: right;">    0.0146524 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         26.7716</td><td style="text-align: right;">1.1652     </td><td style="text-align: right;">  0.304   </td><td style="text-align: right;"> 1.14829  </td></tr>
# <tr><td>TrainViT_500bd083</td><td>TERMINATED</td><td>10.56.7.46:2071664</td><td style="text-align: right;">0.00137465</td><td style="text-align: right;">0.00146941 </td><td style="text-align: right;">  0.945457</td><td>adam       </td><td>linearinterpola_3690</td><td>True     </td><td style="text-align: right;">    0.027259  </td><td style="text-align: right;">     2</td><td style="text-align: right;">         54.249 </td><td style="text-align: right;">0.218083   </td><td style="text-align: right;">  0.937333</td><td style="text-align: right;"> 0.114722 </td></tr>
# <tr><td>TrainViT_3e38d354</td><td>TERMINATED</td><td>10.56.7.46:2071789</td><td style="text-align: right;">0.00372124</td><td style="text-align: right;">0.00300152 </td><td style="text-align: right;">  0.842626</td><td>sgd        </td><td
# (TrainViT pid=2067308) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2067308)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068273) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068273)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068390) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068390)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068493) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068493)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2067308) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_e8b9dbef_1_end_lr=0.0086,lr=0.0001,momentum=0.9544,optimizer=adam,scheduler=constant,use_gpu=True,weight_decay=0.0703_2024-11-02_11-20-03/checkpoint_000000)
# (TrainViT pid=2068273) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_1b154b15_2_end_lr=0.0075,lr=0.0000,momentum=0.8881,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-20-18/checkpoint_000000)
# (TrainViT pid=2068599) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068599)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068390) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_dfa71a53_3_end_lr=0.0066,lr=0.0000,momentum=0.9793,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0150_2024-11-02_11-20-27/checkpoint_000000)
# (TrainViT pid=2068712) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068712)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068493) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_5bc1a2ff_4_end_lr=0.0065,lr=0.0001,momentum=0.9136,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0345_2024-11-02_11-20-34/checkpoint_000000)
# (TrainViT pid=2068843) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068843)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068971) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2068971)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068599) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c4960fb4_5_end_lr=0.0058,lr=0.0001,momentum=0.8672,optimizer=sgd,scheduler=cosineannealinglr,use_gpu=True,weight_decay=0._2024-11-02_11-20-48/checkpoint_000000)
# (TrainViT pid=2069123) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069123)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068712) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b84013fd_6_end_lr=0.0094,lr=0.0265,momentum=0.9628,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-20-56/checkpoint_000000)
# (TrainViT pid=2068843) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_d634c15b_7_end_lr=0.0033,lr=0.0037,momentum=0.8851,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-21-02/checkpoint_000000)
# (TrainViT pid=2069232) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069232)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2068971) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_f10a3b05_8_end_lr=0.0085,lr=0.0000,momentum=0.9112,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=0_2024-11-02_11-21-10/checkpoint_000000)
# (TrainViT pid=2069347) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069347)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069475) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069475)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069123) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_315372e7_9_end_lr=0.0055,lr=0.0001,momentum=0.9770,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-21-25/checkpoint_000000)
# (TrainViT pid=2069623) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069623)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069232) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_376966ef_10_end_lr=0.0091,lr=0.0000,momentum=0.9459,optimizer=adam,scheduler=constant,use_gpu=True,weight_decay=0.0147_2024-11-02_11-21-33/checkpoint_000000)
# (TrainViT pid=2069347) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_500bd083_11_end_lr=0.0014,lr=0.0015,momentum=0.9455,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-21-38/checkpoint_000000)
# (TrainViT pid=2069740) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069740)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069475) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_3e38d354_12_end_lr=0.0037,lr=0.0030,momentum=0.8426,optimizer=sgd,scheduler=cosineannealinglr,use_gpu=True,weight_decay=0_2024-11-02_11-21-45/checkpoint_000000)
# (TrainViT pid=2069852) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069852)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069974) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2069974)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069623) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_37c2e2cb_13_end_lr=0.0016,lr=0.0001,momentum=0.8605,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0433_2024-11-02_11-22-01/checkpoint_000000)
# (TrainViT pid=2069740) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_2f81fb4c_14_end_lr=0.0015,lr=0.0005,momentum=0.9358,optimizer=sgd,scheduler=linearinterpolationlr,use_gpu=True,weight_dec_2024-11-02_11-22-09/checkpoint_000000)
# (TrainViT pid=2070127) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070127)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069852) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_e3211ffa_15_end_lr=0.0027,lr=0.0001,momentum=0.8905,optimizer=adam,scheduler=constant,use_gpu=True,weight_decay=0.0702_2024-11-02_11-22-14/checkpoint_000000)
# (TrainViT pid=2070238) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070238)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2069974) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c36aca79_16_end_lr=0.0012,lr=0.0416,momentum=0.9117,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0103_2024-11-02_11-22-20/checkpoint_000000)
# (TrainViT pid=2070350) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070350)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070467) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070467)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070127) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_480ed446_17_end_lr=0.0041,lr=0.0236,momentum=0.8265,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0568_2024-11-02_11-22-35/checkpoint_000000)
# /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/statsmodels/nonparametric/kernels.py:62: RuntimeWarning: divide by zero encountered in divide
#   kernel_value = np.ones(Xi.size) * h / (num_levels - 1)
# (TrainViT pid=2070639) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070639)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070238) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_206d3535_18_end_lr=0.0064,lr=0.0001,momentum=0.9796,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-22-44/checkpoint_000000)
# (TrainViT pid=2070350) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000000)
# (TrainViT pid=2070750) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070750)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070872) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2070872)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070467) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_23ddade8_20_end_lr=0.0099,lr=0.0100,momentum=0.8866,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-22-55/checkpoint_000000)
# (TrainViT pid=2070639) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_feea7a7c_21_end_lr=0.0032,lr=0.0016,momentum=0.8558,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_d_2024-11-02_11-23-11/checkpoint_000000)
# (TrainViT pid=2070750) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_5a6483dd_22_end_lr=0.0019,lr=0.0865,momentum=0.9882,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0801_2024-11-02_11-23-19/checkpoint_000000)
# (TrainViT pid=2070467) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_23ddade8_20_end_lr=0.0099,lr=0.0100,momentum=0.8866,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-22-55/checkpoint_000001)
# (TrainViT pid=2071079) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b84013fd_6_end_lr=0.0094,lr=0.0265,momentum=0.9628,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-20-56/checkpoint_000000)
# (TrainViT pid=2070872) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_873c99a9_23_end_lr=0.0010,lr=0.0000,momentum=0.8165,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-23-25/checkpoint_000000)
# (TrainViT pid=2071079) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2071079)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070639) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_feea7a7c_21_end_lr=0.0032,lr=0.0016,momentum=0.8558,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_d_2024-11-02_11-23-11/checkpoint_000001)
# (TrainViT pid=2070750) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_5a6483dd_22_end_lr=0.0019,lr=0.0865,momentum=0.9882,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0801_2024-11-02_11-23-19/checkpoint_000001)
# (TrainViT pid=2070872) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_873c99a9_23_end_lr=0.0010,lr=0.0000,momentum=0.8165,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-23-25/checkpoint_000001)
# (TrainViT pid=2071079) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b84013fd_6_end_lr=0.0094,lr=0.0265,momentum=0.9628,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-20-56/checkpoint_000001)
# (TrainViT pid=2071537) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_d634c15b_7_end_lr=0.0033,lr=0.0037,momentum=0.8851,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-21-02/checkpoint_000000)
# (TrainViT pid=2071537) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2071537)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2070639) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_feea7a7c_21_end_lr=0.0032,lr=0.0016,momentum=0.8558,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_d_2024-11-02_11-23-11/checkpoint_000002)
# (TrainViT pid=2071664) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_500bd083_11_end_lr=0.0014,lr=0.0015,momentum=0.9455,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-21-38/checkpoint_000000)
# (TrainViT pid=2070750) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_5a6483dd_22_end_lr=0.0019,lr=0.0865,momentum=0.9882,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0801_2024-11-02_11-23-19/checkpoint_000002)
# (TrainViT pid=2071664) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2071664)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2071789) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_3e38d354_12_end_lr=0.0037,lr=0.0030,momentum=0.8426,optimizer=sgd,scheduler=cosineannealinglr,use_gpu=True,weight_decay=0_2024-11-02_11-21-45/checkpoint_000000)
# (TrainViT pid=2070872) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_873c99a9_23_end_lr=0.0010,lr=0.0000,momentum=0.8165,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-23-25/checkpoint_000002)
# (TrainViT pid=2071789) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2071789)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2071900) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_2f81fb4c_14_end_lr=0.0015,lr=0.0005,momentum=0.9358,optimizer=sgd,scheduler=linearinterpolationlr,use_gpu=True,weight_dec_2024-11-02_11-22-09/checkpoint_000000)
# (TrainViT pid=2071900) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2071900)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2071537) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_d634c15b_7_end_lr=0.0033,lr=0.0037,momentum=0.8851,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-21-02/checkpoint_000001)
# (TrainViT pid=2072035) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_e3211ffa_15_end_lr=0.0027,lr=0.0001,momentum=0.8905,optimizer=adam,scheduler=constant,use_gpu=True,weight_decay=0.0702_2024-11-02_11-22-14/checkpoint_000000)
# (TrainViT pid=2072035) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072035)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2071664) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_500bd083_11_end_lr=0.0014,lr=0.0015,momentum=0.9455,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-21-38/checkpoint_000001)
# (TrainViT pid=2072163) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c36aca79_16_end_lr=0.0012,lr=0.0416,momentum=0.9117,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0103_2024-11-02_11-22-20/checkpoint_000000)
# (TrainViT pid=2071789) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_3e38d354_12_end_lr=0.0037,lr=0.0030,momentum=0.8426,optimizer=sgd,scheduler=cosineannealinglr,use_gpu=True,weight_decay=0_2024-11-02_11-21-45/checkpoint_000001)
# (TrainViT pid=2072163) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072163)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2071900) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_2f81fb4c_14_end_lr=0.0015,lr=0.0005,momentum=0.9358,optimizer=sgd,scheduler=linearinterpolationlr,use_gpu=True,weight_dec_2024-11-02_11-22-09/checkpoint_000001)
# (TrainViT pid=2072289) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_480ed446_17_end_lr=0.0041,lr=0.0236,momentum=0.8265,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0568_2024-11-02_11-22-35/checkpoint_000000)
# (TrainViT pid=2072289) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072289)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072402) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000000)
# (TrainViT pid=2072402) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072402)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072035) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_e3211ffa_15_end_lr=0.0027,lr=0.0001,momentum=0.8905,optimizer=adam,scheduler=constant,use_gpu=True,weight_decay=0.0702_2024-11-02_11-22-14/checkpoint_000001)
# (TrainViT pid=2072534) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072534)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072163) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c36aca79_16_end_lr=0.0012,lr=0.0416,momentum=0.9117,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0103_2024-11-02_11-22-20/checkpoint_000001)
# (TrainViT pid=2072289) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_480ed446_17_end_lr=0.0041,lr=0.0236,momentum=0.8265,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0568_2024-11-02_11-22-35/checkpoint_000001)
# (TrainViT pid=2072663) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072663)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072402) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000001)
# (TrainViT pid=2072791) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2072791)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072534) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_df2a85ed_24_end_lr=0.0055,lr=0.0014,momentum=0.8384,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_d_2024-11-02_11-25-43/checkpoint_000000)
# (TrainViT pid=2072663) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ed3a9014_25_end_lr=0.0035,lr=0.0005,momentum=0.9337,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0663_2024-11-02_11-25-53/checkpoint_000000)
# (TrainViT pid=2072791) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef73f00a_26_end_lr=0.0057,lr=0.0888,momentum=0.8477,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0888_2024-11-02_11-26-00/checkpoint_000000)
# (TrainViT pid=2072402) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000002)
# (TrainViT pid=2072534) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_df2a85ed_24_end_lr=0.0055,lr=0.0014,momentum=0.8384,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_d_2024-11-02_11-25-43/checkpoint_000001)
# (TrainViT pid=2072663) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ed3a9014_25_end_lr=0.0035,lr=0.0005,momentum=0.9337,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0663_2024-11-02_11-25-53/checkpoint_000001)
# (TrainViT pid=2072791) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef73f00a_26_end_lr=0.0057,lr=0.0888,momentum=0.8477,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0888_2024-11-02_11-26-00/checkpoint_000001)
# (TrainViT pid=2072402) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000003)
# (TrainViT pid=2073360) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b84013fd_6_end_lr=0.0094,lr=0.0265,momentum=0.9628,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-20-56/checkpoint_000001)
# (TrainViT pid=2073360) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2073360)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072534) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_df2a85ed_24_end_lr=0.0055,lr=0.0014,momentum=0.8384,optimizer=adamw,scheduler=linearinterpolationlr,use_gpu=True,weight_d_2024-11-02_11-25-43/checkpoint_000002)
# (TrainViT pid=2073492) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c36aca79_16_end_lr=0.0012,lr=0.0416,momentum=0.9117,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0103_2024-11-02_11-22-20/checkpoint_000001)
# (TrainViT pid=2073492) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2073492)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2072663) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ed3a9014_25_end_lr=0.0035,lr=0.0005,momentum=0.9337,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0663_2024-11-02_11-25-53/checkpoint_000002)
# (TrainViT pid=2073624) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_480ed446_17_end_lr=0.0041,lr=0.0236,momentum=0.8265,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0568_2024-11-02_11-22-35/checkpoint_000001)
# (TrainViT pid=2072791) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef73f00a_26_end_lr=0.0057,lr=0.0888,momentum=0.8477,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0888_2024-11-02_11-26-00/checkpoint_000002)
# (TrainViT pid=2073624) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2073624)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2073732) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_23ddade8_20_end_lr=0.0099,lr=0.0100,momentum=0.8866,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-22-55/checkpoint_000001)
# (TrainViT pid=2073360) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b84013fd_6_end_lr=0.0094,lr=0.0265,momentum=0.9628,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-20-56/checkpoint_000002)
# (TrainViT pid=2073732) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2073732)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2073492) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c36aca79_16_end_lr=0.0012,lr=0.0416,momentum=0.9117,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0103_2024-11-02_11-22-20/checkpoint_000002)
# (TrainViT pid=2073624) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_480ed446_17_end_lr=0.0041,lr=0.0236,momentum=0.8265,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0568_2024-11-02_11-22-35/checkpoint_000002)
# (TrainViT pid=2073360) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b84013fd_6_end_lr=0.0094,lr=0.0265,momentum=0.9628,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-20-56/checkpoint_000003) [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (TrainViT pid=2073492) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_c36aca79_16_end_lr=0.0012,lr=0.0416,momentum=0.9117,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0103_2024-11-02_11-22-20/checkpoint_000003)
# (TrainViT pid=2073987) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2073987)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2074114) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2074114)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2073624) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_480ed446_17_end_lr=0.0041,lr=0.0236,momentum=0.8265,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0568_2024-11-02_11-22-35/checkpoint_000003)
# (TrainViT pid=2074244) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2074244)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2073732) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_23ddade8_20_end_lr=0.0099,lr=0.0100,momentum=0.8866,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-22-55/checkpoint_000003)
# (TrainViT pid=2073987) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_87499c0e_27_end_lr=0.0027,lr=0.0814,momentum=0.8018,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-28-12/checkpoint_000000)
# (TrainViT pid=2074114) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_980d56f3_28_end_lr=0.0042,lr=0.0716,momentum=0.8105,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-28-24/checkpoint_000000)
# (TrainViT pid=2073732) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_23ddade8_20_end_lr=0.0099,lr=0.0100,momentum=0.8866,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-22-55/checkpoint_000004)
# (TrainViT pid=2074244) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_9966c718_29_end_lr=0.0090,lr=0.0637,momentum=0.8580,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-28-33/checkpoint_000000)
# (TrainViT pid=2073987) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_87499c0e_27_end_lr=0.0027,lr=0.0814,momentum=0.8018,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-28-12/checkpoint_000001)
# (TrainViT pid=2074114) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_980d56f3_28_end_lr=0.0042,lr=0.0716,momentum=0.8105,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-28-24/checkpoint_000001)
# ...
# (TrainViT pid=2078290) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_91a0d9f6_30_end_lr=0.0063,lr=0.0257,momentum=0.8069,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-30-16/checkpoint_000008)
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000023)
# (TrainViT pid=2077835) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000009) [repeated 2x across cluster]
# (TrainViT pid=2078290) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_91a0d9f6_30_end_lr=0.0063,lr=0.0257,momentum=0.8069,optimizer=adam,scheduler=linearinterpolationlr,use_gpu=True,weight_de_2024-11-02_11-30-16/checkpoint_000009)
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000024)
# (TrainViT pid=2077835) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000010) [repeated 2x across cluster]
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000025) [repeated 2x across cluster]
# (TrainViT pid=2077835) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000011) [repeated 2x across cluster]
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000026) [repeated 2x across cluster]
# (TrainViT pid=2079302) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000005)
# (TrainViT pid=2079302) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2079302)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2076101) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_23ddade8_20_end_lr=0.0099,lr=0.0100,momentum=0.8866,optimizer=adam,scheduler=cosineannealinglr,use_gpu=True,weight_decay=_2024-11-02_11-22-55/checkpoint_000026)
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000027)
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000028) [repeated 3x across cluster]
# (TrainViT pid=2074788) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_b49f2f71_19_end_lr=0.0013,lr=0.0211,momentum=0.8804,optimizer=adamw,scheduler=cosineannealinglr,use_gpu=True,weight_decay_2024-11-02_11-22-49/checkpoint_000029) [repeated 3x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000009) [repeated 3x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000010)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000011)
# (TrainViT pid=2080527) Restored on 10.56.7.46 from checkpoint: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000011)
# (TrainViT pid=2080527) /home/sur06423/miniconda3/envs/deepl/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1704987280714/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (TrainViT pid=2080527)   return F.conv2d(input, weight, bias, self.stride,
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000012)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000012)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000013)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000013)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000014)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000014)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000015)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000015)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000016)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000016)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000017)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000017)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000018)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000018)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000019)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000019)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000020)
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000020)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000021)
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000022) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000023) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000024) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000025) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000026) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000027) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000028) [repeated 2x across cluster]
# (TrainViT pid=2079302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_ef21a89f_32_end_lr=0.0036,lr=0.0218,momentum=0.8728,optimizer=sgd,scheduler=constant,use_gpu=True,weight_decay=0.0565_2024-11-02_11-31-54/checkpoint_000029) [repeated 2x across cluster]
# 2024-11-02 11:54:03,139	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/sur06423/ray_results/Bayesian_Trial_Exp' in 0.2643s.
# 2024-11-02 11:54:03,178	INFO tune.py:1041 -- Total run time: 2039.34 seconds (2038.97 seconds for the tuning loop).
# 2024-11-02 11:54:03,292 [INFO] Best trial config: {'end_lr': 0.0012565454833, 'lr': 0.0211234128545, 'momentum': 0.8804239601905, 'optimizer': 'adamw', 'scheduler': 'cosineannealinglr', 'use_gpu': True, 'weight_decay': 0.023527713218}
# 2024-11-02 11:54:03,294 [INFO] Best trial final validation accuracy: 0.9826666712760925
# (TrainViT pid=2080527) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/sur06423/ray_results/Bayesian_Trial_Exp/TrainViT_0ac0404d_31_end_lr=0.0061,lr=0.0753,momentum=0.8863,optimizer=adamw,scheduler=constant,use_gpu=True,weight_decay=0.0203_2024-11-02_11-30-38/checkpoint_000029)
